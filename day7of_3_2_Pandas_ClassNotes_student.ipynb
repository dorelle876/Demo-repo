# %% [markdown]
# <a href="https://colab.research.google.com/github/dorelle876/Demo-repo/blob/main/day7of_3_2_Pandas_ClassNotes_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas
#
# Pandas is an open source library built on top of NumPy
# * Allows for very fast analysis – data cleaning, preparationmodifications, etc.
# * Built-in visualization features
# * Works well with all types of data.
# * DataFrames
# * Missing Data
# * GroupBy
# * Merging, Joining data
# * etc, etc, etc

# %%
#must import pandas to access its functions in your notebook
import pandas as pd
import numpy as np #we'll also use a little numpy

# %% [markdown]
# ##Series in pandas
#
# Series in Pandas have a labeled index and a datapoint. Series are a part of DataFrames. They are a one-dimensional ndarray with axis labels

# %%
#create a sample series

labels = ['a','b','c']
my_data = [10,20,30]
arr = np.array(my_data)

d = {'a':10, 'b':20, 'c':30}

# %%
pd.Series(data = my_data, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ##Dataframes (df)
#
# Dataframes (df) are a key part of pandas, they are two-dimensional, tabular data that allow you to work with data in columns and rows.

# %%
#create a dataframe wiht random values using numpy

from numpy.random import randn

np.random.seed(123)

# %%
df = pd.DataFrame(randn(5,4), #creating a new dataframe, with five rows, four columns
                  ['A','B','C','D','E'],['W','X','Y','Z']) #labeling the rows and columns

df
# Out:
#           W         X         Y         Z
# A -1.085631  0.997345  0.282978 -1.506295
# B -0.578600  1.651437 -2.426679 -0.428913
# C  1.265936 -0.866740 -0.678886 -0.094709
# D  1.491390 -0.638902 -0.443982 -0.434351
# E  2.205930  2.186786  1.004054  0.386186

# %% [markdown]
# ##Dealing with rows and columns

# %% [markdown]
# Select columns, pass a list of column names

# %%
#returns a vertical slice of the data with only columns W,X
#does not affect the original dataframe

df[['W','X']]

# %% [markdown]
# Create new columns in dataframe

# %%
df['new'] = df['W'] + df['Y']

df

# %% [markdown]
# Deleting columns

# %%
#delete using df.drop()
#inplace=True means the operation modifies the underlying data
#instead of returning anything

df.drop('new', axis=1, inplace=True) 

df

# %%
#creating a new dataframe with a subset of our data

df2 = df[['W','X']]
df2
# Out:
#           W         X
# A -1.085631  0.997345
# B -0.578600  1.651437
# C  1.265936 -0.866740
# D  1.491390 -0.638902
# E  2.205930  2.186786

# %% [markdown]
# Deleting rows

# %%
df.drop('E', axis = 0)
# Out:
#           W         X         Y         Z
# A -1.085631  0.997345  0.282978 -1.506295
# B -0.578600  1.651437 -2.426679 -0.428913
# C  1.265936 -0.866740 -0.678886 -0.094709
# D  1.491390 -0.638902 -0.443982 -0.434351

# %% [markdown]
# Selecting rows using loc and iloc

# %%
#loc accesses rows using the row label

df.loc['C']
# Out:
# W    1.265936
# X   -0.866740
# Y   -0.678886
# Z   -0.094709
# Name: C, dtype: float64

# %%
#iloc accesses rows using the index position

df.iloc[2]
# Out:
# W    1.265936
# X   -0.866740
# Y   -0.678886
# Z   -0.094709
# Name: C, dtype: float64

# %% [markdown]
# ##Filtering

# %%
#check to see if each value is greater than 0

df > 0
# Out:
#        W      X      Y      Z
# A  False   True   True  False
# B  False   True  False  False
# C   True  False  False  False
# D   True  False  False  False
# E   True   True   True   True

# %%
#save it as a variable called booldf

booldf = df > 0

booldf
# Out:
#        W      X      Y      Z
# A  False   True   True  False
# B  False   True  False  False
# C   True  False  False  False
# D   True  False  False  False
# E   True   True   True   True

# %%
# pass booldf into original dataframe 
#to see values where condition was true

df[booldf]
# Out:
#           W         X         Y         Z
# A       NaN  0.997345  0.282978       NaN
# B       NaN  1.651437       NaN       NaN
# C  1.265936       NaN       NaN       NaN
# D  1.491390       NaN       NaN       NaN
# E  2.205930  2.186786  1.004054  0.386186

# %%
#combine filter into one statement

df[df>0]
# Out:
#           W         X         Y         Z
# A       NaN  0.997345  0.282978       NaN
# B       NaN  1.651437       NaN       NaN
# C  1.265936       NaN       NaN       NaN
# D  1.491390       NaN       NaN       NaN
# E  2.205930  2.186786  1.004054  0.386186

# %% [markdown]
# Filtering based on criteria in a specific column

# %%
df[df['Z']<0]
# Out:
#           W         X         Y         Z
# A -1.085631  0.997345  0.282978 -1.506295
# B -0.578600  1.651437 -2.426679 -0.428913
# C  1.265936 -0.866740 -0.678886 -0.094709
# D  1.491390 -0.638902 -0.443982 -0.434351

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# C  1.265936 -0.866740 -0.678886 -0.094709
# D  1.491390 -0.638902 -0.443982 -0.434351
# E  2.205930  2.186786  1.004054  0.386186

# %% [markdown]
# Renaming columns

# %%
#use df.rename and map old names to new names
df = df.rename(columns={'W':'Wnum', 'X': 'Xnum'})
#creates a new copy of df
df
# Out:
#        Wnum      Xnum         Y         Z
# A -1.085631  0.997345  0.282978 -1.506295
# B -0.578600  1.651437 -2.426679 -0.428913
# C  1.265936 -0.866740 -0.678886 -0.094709
# D  1.491390 -0.638902 -0.443982 -0.434351
# E  2.205930  2.186786  1.004054  0.386186

# %%
#or rename on the existing dataframe using inplace=True

df.rename(columns={'Y':'Ynum', 'Z':'Znum'}, inplace=True)

# %% [markdown]
# #YOUR TURN 1
#
# Use the random number dataset below to do the following:
#
# * Create a new dataframe with only the first two columns.
# * In the new dataframe, rename the columns.
# * In the new dataframe, create a new column with values equal to the product of the first two columns.
# * In the original dataframe, drop the fifth row.

# %%
my_df = pd.DataFrame(randn(5,4), #creating a new dataframe, with five rows, four columns
                  ['A','B','C','D','E'],['W','X','Y','Z']) #labeling the rows and columns

my_df
# Out:
#           W         X         Y         Z
# A  0.737369  1.490732 -0.935834  1.175829
# B -1.253881 -0.637752  0.907105 -1.428681
# C -0.140069 -0.861755 -0.255619 -2.798589
# D -1.771533 -0.699877  0.927462 -0.173636
# E  0.002846  0.688223 -0.879536  0.283627

# %%
new_df = my_df[['W','X']]
new_df
# Out:
#           W         X
# A  0.737369  1.490732
# B -1.253881 -0.637752
# C -0.140069 -0.861755
# D -1.771533 -0.699877
# E  0.002846  0.688223

# %%
new_df.rename(columns={'W':'Win', 'X': 'Xray'})
# Out:
#         Win      Xray
# A  0.737369  1.490732
# B -1.253881 -0.637752
# C -0.140069 -0.861755
# D -1.771533 -0.699877
# E  0.002846  0.688223

# %%
new_df['new'] = new_df['Win'] * new_df['Xray']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Win'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-9f81f32c3922> in <module>()
# ----> 1 my_df['new'] = new_df['Win'] * new_df['Xray']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'Win'

# %%
my_df.drop('E', axis = 0)
# Out:
#           W         X         Y         Z
# A  1.255237 -0.688869  1.660952  0.807308
# B -0.314758 -1.085902 -0.732462 -1.212523
# C  2.087113  0.164441  1.150206 -1.267352
# D  0.181035  1.177862 -0.335011  1.031114

# %% [markdown]
# #Working with a dataset
#
# Old Faithful eruption data, with two variables: time of eruption and waiting time until next eruption (in minutes)

# %%
#importing data from a csv (which is stored in our class github)
faithful_df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/faithful.csv')

# %%
faithful_df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/faithful.csv'), index_col=0).
# Out:
#   File "<ipython-input-41-46f56459a953>", line 1
#     faithful_df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/faithful.csv'), index_col=0).
#                                                                                                                                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# Inspecting dataframe to understand its size, labels and elements

# %%
#make sure it's a dataframe
type(faithful_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#shape shows the number of rows and columns
faithful_df.shape
# Out:
# (272, 3)

# %%
#columns shows the names of the columns
faithful_df.columns
# Out:
# Index(['Unnamed: 0', 'eruptions', 'waiting'], dtype='object')

# %%
#head shows the first rows of data
#5 rows by default
faithful_df.head()
# Out:
#    Unnamed: 0  eruptions  waiting
# 0           1      3.600       79
# 1           2      1.800       54
# 2           3      3.333       74
# 3           4      2.283       62
# 4           5      4.533       85

# %%
#you can see however many rows you want
faithful_df.head(20)
# Out:
#     Unnamed: 0  eruptions  waiting
# 0            1      3.600       79
# 1            2      1.800       54
# 2            3      3.333       74
# 3            4      2.283       62
# 4            5      4.533       85
# 5            6      2.883       55
# 6            7      4.700       88
# 7            8      3.600       85
# 8            9      1.950       51
# 9           10      4.350       85
# 10          11      1.833       54
# 11          12      3.917       84
# 12          13      4.200       78
# 13          14      1.750       47
# 14          15      4.700       83
# 15          16      2.167       52
# 16          17      1.750       62
# 17          18      4.800       84
# 18          19      1.600       52
# 19          20      4.250       79

# %%
#shows the bottom rows
#five by default
faithful_df.tail()
# Out:
#      Unnamed: 0  eruptions  waiting
# 267         268      4.117       81
# 268         269      2.150       46
# 269         270      4.417       90
# 270         271      1.817       46
# 271         272      4.467       74

# %%
#or you can see however many you want
faithful_df.tail(10)
# Out:
#      Unnamed: 0  eruptions  waiting
# 262         263      1.850       58
# 263         264      4.250       83
# 264         265      1.983       43
# 265         266      2.250       60
# 266         267      4.750       75
# 267         268      4.117       81
# 268         269      2.150       46
# 269         270      4.417       90
# 270         271      1.817       46
# 271         272      4.467       74

# %%
faithful_df.head(100)
# Out:
#     Unnamed: 0  eruptions  waiting
# 0            1      3.600       79
# 1            2      1.800       54
# 2            3      3.333       74
# 3            4      2.283       62
# 4            5      4.533       85
# ..         ...        ...      ...
# 95          96      4.300       72
# 96          97      4.667       84
# 97          98      3.750       75
# 98          99      1.867       51
# 99         100      4.900       82
#
# [100 rows x 3 columns]

# %%
#count non-NaN cells for each column or row
#ie the ones with data in them
#summarizes by column by default, or use axis=1 for rows
faithful_df.count()
# Out:
# Unnamed: 0    272
# eruptions     272
# waiting       272
# dtype: int64

# %%
#describe is a great summary of the data in each column
faithful_df.describe()
# Out:
#        Unnamed: 0   eruptions     waiting
# count  272.000000  272.000000  272.000000
# mean   136.500000    3.487783   70.897059
# std     78.663842    1.141371   13.594974
# min      1.000000    1.600000   43.000000
# 25%     68.750000    2.162750   58.000000
# 50%    136.500000    4.000000   76.000000
# 75%    204.250000    4.454250   82.000000
# max    272.000000    5.100000   96.000000

# %%
#returns maximum of values of the specific axis
#over columns by default
faithful_df.max()
# Out:
# Unnamed: 0    272.0
# eruptions       5.1
# waiting        96.0
# dtype: float64

# %%
faithful_df.min()
# Out:
# Unnamed: 0     1.0
# eruptions      1.6
# waiting       43.0
# dtype: float64

# %%
faithful_df.std()
# Out:
# Unnamed: 0    78.663842
# eruptions      1.141371
# waiting       13.594974
# dtype: float64

# %%
faithful_df.median()
# Out:
# Unnamed: 0    136.5
# eruptions       4.0
# waiting        76.0
# dtype: float64

# %% [markdown]
# ##YOUR TURN 2
#
# Using this dataset:
# * How many non-null datapoints are in each column?
# * Find the range of values
# * Find the mean
# * Find the median
# * Find all at once

# %%
faithful_df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/faithful.csv')

# %%
type(faithful_df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.max()
# Out:
# Wnum    2.205930
# Xnum    2.186786
# Ynum    1.004054
# Znum    0.386186
# dtype: float64

# %%
df.min()
# Out:
# Wnum   -1.085631
# Xnum   -0.866740
# Ynum   -2.426679
# Znum   -1.506295
# dtype: float64

# %%
df.mean()
# Out:
# Wnum    0.659805
# Xnum    0.665985
# Ynum   -0.452503
# Znum   -0.415616
# dtype: float64

# %%
df.median()
# Out:
# Wnum    1.265936
# Xnum    0.997345
# Ynum   -0.443982
# Znum   -0.428913
# dtype: float64

# %%
df.describe()
# Out:
#            Wnum      Xnum      Ynum      Znum
# count  5.000000  5.000000  5.000000  5.000000
# mean   0.659805  0.665985 -0.452503 -0.415616
# std    1.416830  1.364343  1.285611  0.695697
# min   -1.085631 -0.866740 -2.426679 -1.506295
# 25%   -0.578600 -0.638902 -0.678886 -0.434351
# 50%    1.265936  0.997345 -0.443982 -0.428913
# 75%    1.491390  1.651437  0.282978 -0.094709
# max    2.205930  2.186786  1.004054  0.386186

# %% [markdown]
# Working with only one column at a time

# %%
faithful_df['eruptions']
# Out:
# 0      3.600
# 1      1.800
# 2      3.333
# 3      2.283
# 4      4.533
#        ...
# 267    4.117
# 268    2.150
# 269    4.417
# 270    1.817
# 271    4.467
# Name: eruptions, Length: 272, dtype: float64

# %%
#create a new dataset with only one column
eruption_list = faithful_df['eruptions']

# %%
eruption_list
# Out:
# 0      3.600
# 1      1.800
# 2      3.333
# 3      2.283
# 4      4.533
#        ...
# 267    4.117
# 268    2.150
# 269    4.417
# 270    1.817
# 271    4.467
# Name: eruptions, Length: 272, dtype: float64

# %%
#note that it's NOT automatically a dataframe
type(eruption_list)
# Out:
# pandas.core.series.Series

# %%
#we have to explicitly make it a dataframe
pd.DataFrame(eruption_list)
# Out:
#      eruptions
# 0        3.600
# 1        1.800
# 2        3.333
# 3        2.283
# 4        4.533
# ..         ...
# 267      4.117
# 268      2.150
# 269      4.417
# 270      1.817
# 271      4.467
#
# [272 rows x 1 columns]

# %%
# syntax is df('colum).function()
faithful_df['waiting'].median()
# Out:
# 76.0

# %% [markdown]
# #YOUR TURN 3
#
# Using this dataframe, run multiple functions on a couple different columns. Check your output and see if it's what you expected.

# %%
faithful_df['waiting'].median()
# Out:
# 76.0

# %%
faithful_df['eruptions']
# Out:
# 0      3.600
# 1      1.800
# 2      3.333
# 3      2.283
# 4      4.533
#        ...
# 267    4.117
# 268    2.150
# 269    4.417
# 270    1.817
# 271    4.467
# Name: eruptions, Length: 272, dtype: float64

# %%
faithful_df['eruptions'].std
# Out:
# <bound method Series.std of 0      3.600
# 1      1.800
# 2      3.333
# 3      2.283
# 4      4.533
#        ...
# 267    4.117
# 268    2.150
# 269    4.417
# 270    1.817
# 271    4.467
# Name: eruptions, Length: 272, dtype: float64>

# %% [markdown]
# # A little bit of exploratory data viz

# %%
#import viz package matplotlib

import matplotlib.pyplot as plot
# %matplotlib inline 
#this renders the plots in our notebooks

# %%
#make a histogram

faithful_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa053a6fe50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa05357f450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa053534a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa0534ebfd0>]],
#       dtype=object)

# %%
faithful_df.plot()

# %%
faithful_df.plot(kind = 'scatter', x = 'waiting', y = 'eruptions')

# %% [markdown]
# ## Practice
# Play with your plots a little bit. Use this website for inspiration and code snippets:
#
# https://bit.ly/2WPTwtW

# %%
df = pd.DataFrame(randn(5,4),
                  ['A','B','C','D','E'],['W','X','Y','Z']) #labeling the rows and columns
df
# Out:
#           W         X         Y         Z
# A -0.805367 -1.727669 -0.390900  0.573806
# B  0.338589 -0.011830  2.392365  0.412912
# C  0.978736  2.238143 -1.294085 -1.038788
# D  1.743712 -0.798063  0.029683  1.069316
# E  0.890706  1.754886  1.495644  1.069393

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa053051050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa052c8e750>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa052c64710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa052c1ad10>]],
#       dtype=object)

# %%
df.plot()

# %% [markdown]
# #Let's analyze a dataset together
#
# Data from NYC's 311 system. Use this website for information about the dataset, including a record layout:
#
# [NYC Open Data](https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9)

# %%
import pandas as pd

df_311 = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/311_Service_Requests_from_2019May.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_311.head()
# Out:
#    Unique Key  ...                                  Location
# 0    42680103  ...  (40.682565064146196, -73.81406015056832)
# 1    42530481  ...  (40.738790792032844, -74.00022373020307)
# 2    42527619  ...   (40.79804015465285, -73.96930001020544)
# 3    42526597  ...   (40.67590510222738, -73.86665990579837)
# 4    42526595  ...   (40.76536704921336, -73.93154011254339)
#
# [5 rows x 21 columns]

# %% [markdown]
# # YOUR TURN 4
#
# Run some code to get to know your dataframe.
#
# * Look at the first five rows.
# * How many rows and columns are there
# * What are the names of the columns?
# * Quickly summarize the data in each numerical column.
# * Look at your results. Is this something that makes sense to do on this data? Why or why not?

# %%
df_311.head()
# Out:
#    Unique Key  ...                                  Location
# 0    42680103  ...  (40.682565064146196, -73.81406015056832)
# 1    42530481  ...  (40.738790792032844, -74.00022373020307)
# 2    42527619  ...   (40.79804015465285, -73.96930001020544)
# 3    42526597  ...   (40.67590510222738, -73.86665990579837)
# 4    42526595  ...   (40.76536704921336, -73.93154011254339)
#
# [5 rows x 21 columns]

# %%
type(df_311)
pd.DataFrame(df_311)
# Out:
#        Unique Key  ...                                  Location
# 0        42680103  ...  (40.682565064146196, -73.81406015056832)
# 1        42530481  ...  (40.738790792032844, -74.00022373020307)
# 2        42527619  ...   (40.79804015465285, -73.96930001020544)
# 3        42526597  ...   (40.67590510222738, -73.86665990579837)
# 4        42526595  ...   (40.76536704921336, -73.93154011254339)
# ...           ...  ...                                       ...
# 69632    42634163  ...    (40.81459022279005, -73.9138921969276)
# 69633    42624568  ...    (40.5493782172547, -74.14025187299927)
# 69634    42638781  ...    (40.85291902458401, -73.9199659548619)
# 69635    42637637  ...     (40.694573889726, -73.91089180797395)
# 69636    42637636  ...   (40.69089111172563, -73.98595118240841)
#
# [69637 rows x 21 columns]

# %%
df_311.count()
# Out:
# Unique Key                69637
# Created Date              69637
# Closed Date               64626
# Agency                    69637
# Complaint Type            69637
# Location Type             53978
# Incident Zip              67389
# Incident Address          59033
# Street Name               59032
# Address Type              68307
# City                      67416
# Landmark                     16
# Facility Type             24081
# Status                    69637
# Due Date                  32839
# Resolution Description    63579
# BBL                       55702
# Borough                   69637
# Latitude                  65634
# Longitude                 65634
# Location                  65634
# dtype: int64

# %%
df_311.describe()
# Out:
#          Unique Key           BBL      Latitude     Longitude
# count  6.963700e+04  5.570200e+04  65634.000000  65634.000000
# mean   4.260307e+07  2.869652e+09     40.723149    -73.924517
# std    5.269818e+04  1.184250e+09      0.083621      0.085089
# min    4.251278e+07  0.000000e+00     40.500025    -74.252279
# 25%    4.258004e+07  2.030690e+09     40.664461    -73.972161
# 50%    4.260019e+07  3.034830e+09     40.716443    -73.929758
# 75%    4.262095e+07  4.023330e+09     40.780783    -73.874064
# max    4.297343e+07  5.080480e+09     40.912869    -73.700597

# %% [markdown]
# #Sorting data

# %%
#defaults to ascending order
df_311.sort_values('Created Date')
# Out:
#        Unique Key  ...                                  Location
# 0        42680103  ...  (40.682565064146196, -73.81406015056832)
# 12       42520595  ...   (40.74193771952419, -73.98267813378038)
# 11       42524126  ...   (40.63529885534431, -73.96330029572755)
# 9        42519734  ...  (40.603139635103894, -73.75314685334116)
# 8        42526596  ...   (40.723414081593475, -73.9883109901953)
# ...           ...  ...                                       ...
# 63658    42627943  ...    (40.7559537758779, -73.93358914468376)
# 63659    42631065  ...   (40.58437280054309, -73.81747652666041)
# 63660    42631729  ...   (40.62485417524056, -74.11067990662339)
# 63661    42626088  ...  (40.787488359790885, -73.83919357343625)
# 63662    42624584  ...  (40.675463847815614, -73.95711703408162)
#
# [69637 rows x 21 columns]

# %%
#use this for descending

df_311.sort_values('Created Date', ascending = False)
# Out:
#        Unique Key  ...                                  Location
# 63662    42624584  ...  (40.675463847815614, -73.95711703408162)
# 63661    42626088  ...  (40.787488359790885, -73.83919357343625)
# 63660    42631729  ...   (40.62485417524056, -74.11067990662339)
# 63659    42631065  ...   (40.58437280054309, -73.81747652666041)
# 63658    42627943  ...    (40.7559537758779, -73.93358914468376)
# ...           ...  ...                                       ...
# 9        42519734  ...  (40.603139635103894, -73.75314685334116)
# 10       42613472  ...   (40.73148270284829, -73.94627094704092)
# 11       42524126  ...   (40.63529885534431, -73.96330029572755)
# 12       42520595  ...   (40.74193771952419, -73.98267813378038)
# 0        42680103  ...  (40.682565064146196, -73.81406015056832)
#
# [69637 rows x 21 columns]

# %% [markdown]
# ## Practice sorting

# %% [markdown]
# #Filtering columns

# %%
#select a column

df_311['Complaint Type']
# Out:
# 0          Water System
# 1        Food Poisoning
# 2        Food Poisoning
# 3        Food Poisoning
# 4        Food Poisoning
#               ...
# 69632    Food Poisoning
# 69633    Standing Water
# 69634    Food Poisoning
# 69635    Food Poisoning
# 69636    Food Poisoning
# Name: Complaint Type, Length: 69637, dtype: object

# %%
#select multiple columns

df_311[['Complaint Type', 'Borough']]
# Out:
#        Complaint Type        Borough
# 0        Water System         QUEENS
# 1      Food Poisoning      MANHATTAN
# 2      Food Poisoning      MANHATTAN
# 3      Food Poisoning       BROOKLYN
# 4      Food Poisoning         QUEENS
# ...               ...            ...
# 69632  Food Poisoning          BRONX
# 69633  Standing Water  STATEN ISLAND
# 69634  Food Poisoning          BRONX
# 69635  Food Poisoning       BROOKLYN
# 69636  Food Poisoning       BROOKLYN
#
# [69637 rows x 2 columns]

# %%
#create a new df out of them

df_311_2 = df_311[['Complaint Type', 'Borough']]

# %% [markdown]
# ##Practice filtering by columns

# %% [markdown]
# ##Filtering by rows

# %%
#create a new dataframe to hold our results

df_food_poisoning = df_311[df_311['Complaint Type'] == 'Food Poisoning']

df_food_poisoning
# Out:
#        Unique Key  ...                                  Location
# 1        42530481  ...  (40.738790792032844, -74.00022373020307)
# 2        42527619  ...   (40.79804015465285, -73.96930001020544)
# 3        42526597  ...   (40.67590510222738, -73.86665990579837)
# 4        42526595  ...   (40.76536704921336, -73.93154011254339)
# 5        42524590  ...    (40.7263640809953, -73.98332077635699)
# ...           ...  ...                                       ...
# 69631    42634164  ...   (40.77897233667541, -73.98135058363005)
# 69632    42634163  ...    (40.81459022279005, -73.9138921969276)
# 69634    42638781  ...    (40.85291902458401, -73.9199659548619)
# 69635    42637637  ...     (40.694573889726, -73.91089180797395)
# 69636    42637636  ...   (40.69089111172563, -73.98595118240841)
#
# [81 rows x 21 columns]

# %%
#Add multiple criteria using & and or

df_food_poisoning_bronx = df_311[(df_311['Complaint Type'] == 'Food Poisoning') 
          & (df_311['Borough'] == 'BROOKLYN')] 

df_food_poisoning_bronx
# Out:
#        Unique Key  ...                                  Location
# 3        42526597  ...   (40.67590510222738, -73.86665990579837)
# 8221     42546266  ...  (40.633728991185656, -73.96378754662472)
# 24365    42586376  ...  (40.624014001229156, -74.03084689095088)
# 24367    42589864  ...   (40.69064190997677, -73.99189743966743)
# 30603    42595351  ...  (40.680491558682455, -73.93756172956628)
# 36060    42603504  ...   (40.70226325776776, -73.92844555498132)
# 36061    42603293  ...   (40.70416369785813, -73.93017472076156)
# 44726    42611826  ...   (40.65127602271148, -73.86891466875586)
# 44729    42612861  ...   (40.57529925188215, -73.96884803240036)
# 44734    42607146  ...   (40.65173102723366, -73.91879099575826)
# 61582    42628360  ...    (40.6770193098597, -73.97233001831667)
# 61583    42627480  ...  (40.610038453325224, -73.95530063922277)
# 61586    42633073  ...  (40.667823543138425, -73.93121487397924)
# 69630    42634256  ...  (40.664753842867476, -73.86733462088748)
# 69635    42637637  ...     (40.694573889726, -73.91089180797395)
# 69636    42637636  ...   (40.69089111172563, -73.98595118240841)
#
# [16 rows x 21 columns]

# %%
#filter for noise complaints

df_311[df_311['Complaint Type'] == 'Noise']
# Out:
#        Unique Key  ...                                  Location
# 11       42524126  ...   (40.63529885534431, -73.96330029572755)
# 24       42524125  ...  (40.889408390994824, -73.81917795993981)
# 37       42525163  ...  (40.728596115948555, -73.98767146528662)
# 50       42530241  ...  (40.726539056574374, -73.97909950322429)
# 58       42530240  ...  (40.726165603776785, -73.97820486905297)
# ...           ...  ...                                       ...
# 69550    42628050  ...   (40.75316776913413, -73.99787049501836)
# 69551    42626947  ...   (40.81126609731296, -73.95780983086226)
# 69552    42624631  ...   (40.76531021023602, -73.99133241757852)
# 69579    42628061  ...    (40.6961448394419, -73.74339016602585)
# 69608    42631456  ...  (40.721822528608165, -73.99344493099719)
#
# [1805 rows x 21 columns]

# %%
#filter for noise complaints and count them 

df_311[df_311['Complaint Type'] == 'Noise'].count()
# Out:
# Unique Key                1805
# Created Date              1805
# Closed Date               1791
# Agency                    1805
# Complaint Type            1805
# Location Type                0
# Incident Zip              1785
# Incident Address          1342
# Street Name               1342
# Address Type              1805
# City                      1785
# Landmark                     0
# Facility Type                0
# Status                    1805
# Due Date                     0
# Resolution Description    1795
# BBL                       1165
# Borough                   1805
# Latitude                  1769
# Longitude                 1769
# Location                  1769
# dtype: int64

# %%
#filter for noise complaints using fuzzy matching

df_311[df_311['Complaint Type'].str.contains('Noise')]

# %% [markdown]
# ##Practice filtering by rows

# %%
df_311[df_311['city'] == 'BROOKLYN'].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'city'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-02559f7f4d0d> in <module>()
# ----> 1 df_311[df_311['city'] == 'BROOKLYN'].count()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'city'

# %%
df_311

# %% [markdown]
# #Aggregating data
#
# Aggregating means putting data into groups and then doing math on those groups (counting, summing, averaging, etc)

# %% [markdown]
# Using group by to aggregate by certain columns

# %%
#groups by borough and counts the number of unique keys
df_311.groupby(['Borough'])['Unique Key'].count()
# Out:
# Borough
# BRONX            10925
# BROOKLYN         22247
# MANHATTAN        13133
# QUEENS           18623
# STATEN ISLAND     3848
# Unspecified        861
# Name: Unique Key, dtype: int64

# %%
df_311.groupby(['Borough'])['Unique Key'].count().sort_values(ascending=True)
# Out:
# Borough
# Unspecified        861
# STATEN ISLAND     3848
# BRONX            10925
# MANHATTAN        13133
# QUEENS           18623
# BROOKLYN         22247
# Name: Unique Key, dtype: int64

# %%
df_311.groupby(['Borough'])['Unique Key'].count().sort_values(ascending=False)
# Out:
# Borough
# BROOKLYN         22247
# QUEENS           18623
# MANHATTAN        13133
# BRONX            10925
# STATEN ISLAND     3848
# Unspecified        861
# Name: Unique Key, dtype: int64

# %%
df_311.groupby(['Landmark'])['Unique Key'].count()
# Out:
# Landmark
# CENTRAL PARK              4
# CITY HALL                 1
# CONEY ISLAND HOSPITAL     1
# FT TOTTEN                 1
# GRAND CENTRAL TERM        1
# J F K AIRPORT             2
# LA GUARDIA AIRPORT        1
# PS 44                     1
# UNDERWOOD PARK            1
# UNION SQUARE PARK         1
# WASHINGTON SQUARE PARK    2
# Name: Unique Key, dtype: int64

# %%
df_311.groupby(['Landmark'])['Unique Key'].count().sort_values(ascending=False)
# Out:
# Landmark
# CENTRAL PARK              4
# WASHINGTON SQUARE PARK    2
# J F K AIRPORT             2
# UNION SQUARE PARK         1
# UNDERWOOD PARK            1
# PS 44                     1
# LA GUARDIA AIRPORT        1
# GRAND CENTRAL TERM        1
# FT TOTTEN                 1
# CONEY ISLAND HOSPITAL     1
# CITY HALL                 1
# Name: Unique Key, dtype: int64

# %%
df_311.groupby(['Complaint Type'])['Unique Key'].count()
# Out:
# Complaint Type
# APPLIANCE                         313
# Advocate - Other                    4
# Advocate-Co-opCondo Abatement       1
# Advocate-Personal Exemptions        5
# Advocate-Prop Refunds/Credits       6
#                                  ...
# WATER LEAK                        726
# Water Conservation                 74
# Water Quality                      40
# Water System                     1519
# Window Guard                        1
# Name: Unique Key, Length: 186, dtype: int64

# %%
df_311.groupby(['Complaint Type'])['Unique Key'].count().sort_values(ascending=False)
# Out:
# Complaint Type
# Noise - Residential                    5838
# Request Large Bulky Item Collection    5301
# Illegal Parking                        5257
# Blocked Driveway                       3391
# Street Condition                       3080
#                                        ...
# Mosquitoes                                1
# Illegal Fireworks                         1
# Disorderly Youth                          1
# LinkNYC                                   1
# Window Guard                              1
# Name: Unique Key, Length: 186, dtype: int64

# %% [markdown]
# #Missing data
#
#  There are a few ways to check for missing values.

# %%
import numpy as np

# %%
df = {'A':[1,2,np.nan], 'B':[3,np.nan, np.nan]} #creating a sample df with missing values
df = pd.DataFrame(df) #convert to a dataframe

df
# Out:
#      A    B
# 0  1.0  3.0
# 1  2.0  NaN
# 2  NaN  NaN

# %%
#check for any missing values
#isnull() works for small datasets but isn't practical for large ones
df.isnull()
# Out:
#        A      B
# 0  False  False
# 1  False   True
# 2   True   True

# %%
#add up missing values by column
df.isnull().sum()
# Out:
# A    1
# B    2
# dtype: int64

# %%
#add up total missing values
df.isnull().sum().sum()
# Out:
# 3

# %% [markdown]
# #Practice
#
# How many nans are in the 311 data?

# %%
df_311.isnull()
# Out:
#        Unique Key  Created Date  Closed Date  ...  Latitude  Longitude  Location
# 0           False         False        False  ...     False      False     False
# 1           False         False        False  ...     False      False     False
# 2           False         False        False  ...     False      False     False
# 3           False         False        False  ...     False      False     False
# 4           False         False        False  ...     False      False     False
# ...           ...           ...          ...  ...       ...        ...       ...
# 69632       False         False        False  ...     False      False     False
# 69633       False         False        False  ...     False      False     False
# 69634       False         False        False  ...     False      False     False
# 69635       False         False        False  ...     False      False     False
# 69636       False         False        False  ...     False      False     False
#
# [69637 rows x 21 columns]

# %%
df_311.isnull().sum()
# Out:
# Unique Key                    0
# Created Date                  0
# Closed Date                5011
# Agency                        0
# Complaint Type                0
# Location Type             15659
# Incident Zip               2248
# Incident Address          10604
# Street Name               10605
# Address Type               1330
# City                       2221
# Landmark                  69621
# Facility Type             45556
# Status                        0
# Due Date                  36798
# Resolution Description     6058
# BBL                       13935
# Borough                       0
# Latitude                   4003
# Longitude                  4003
# Location                   4003
# dtype: int64

# %%
df_311.isnull().sum().sum()
# Out:
# 231655

# %% [markdown]
# Dropping missing values

# %%
#drop all rows with missing values
df.dropna()
# Out:
#      A    B
# 0  1.0  3.0

# %%
#drop all  columns that contain nans
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %%
df.fillna(3)
# Out:
#      A    B
# 0  1.0  3.0
# 1  2.0  3.0
# 2  3.0  3.0
